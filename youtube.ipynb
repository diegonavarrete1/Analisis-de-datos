# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
df = pd.read_csv('/kaggle/input/datasets/yusufmurtaza01/youtube-top-channels-2026/global_top4k.csv')


df['Subscribers']= df['Subscribers'].sort_values(ascending= False)
df= df.dropna(subset= 'Subscribers')
num= df.shape[0]
df[['Subscribers', 'Total Views', 'Total Videos']] = \
    df[['Subscribers', 'Total Views', 'Total Videos']].astype(float)
pd.options.display.float_format = '{:,.0f}'.format
youtube= df[df['Subscribers']>= 1000000]
channels_under_1m= num- youtube.shape[0]
print(youtube.info())
print(youtube.head(1))
print(youtube['Total Views'].isna().sum())
print('number of channels under 1M subscribers:', channels_under_1m)
print(youtube['Subscribers'].corr(youtube['Total Views']))
youtube['avg_views']= youtube['Total Views']/ youtube['Total Videos']
print(youtube.head(5))
print(youtube['Country'].value_counts(ascending= False))
corr_sub_videos=youtube['Subscribers'].corr(youtube['Total Videos'])
print(corr_sub_videos)
max_videos= (youtube.sort_values(by = 'Total Videos', ascending= False).head(5))
print(max_videos)

mean_country = youtube.groupby('Country')['avg_views'].mean().sort_values(ascending=False)
print(mean_country)
best_per_country = youtube.loc[
    youtube.groupby('Country')['Subscribers'].idxmax()
]
print('Lista de los canales con mas suscriptores por cada pais:', best_per_country[['Country', 'Channel Name', 'Subscribers']])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1177 entries, 0 to 1176
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Global Rank   1177 non-null   int64
#  1   Channel ID    1177 non-null   object
#  2   Channel Name  1177 non-null   object
#  3   Subscribers   1177 non-null   float64
#  4   Total Views   1177 non-null   float64
#  5   Total Videos  1177 non-null   float64
#  6   Country       1177 non-null   object
#  7   Description   1131 non-null   object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 82.8+ KB
# None
#    Global Rank                Channel ID Channel Name  Subscribers  \
# 0            1  UCX6OQ3DkcsbYNE6H8uQQuVA      MrBeast  474,000,000
#
#       Total Views  Total Videos Country  \
# 0 116,005,659,874           956      US
#
#                                          Description
# 0  SUBSCRIBE FOR A COOKIE! New MrBeast or MrBeast...
# 0
# ...
